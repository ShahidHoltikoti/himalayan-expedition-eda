# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
data  = pd.read_csv("data.csv")

# %%
data.head()
# Out:
#   expedition_id     member_id peak_id   peak_name  year  season sex   age  \
# 0     AMAD78301  AMAD78301-01    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 1     AMAD78301  AMAD78301-02    AMAD  Ama Dablam  1978  Autumn   M  41.0
# 2     AMAD78301  AMAD78301-03    AMAD  Ama Dablam  1978  Autumn   M  27.0
# 3     AMAD78301  AMAD78301-04    AMAD  Ama Dablam  1978  Autumn   M  40.0
# 4     AMAD78301  AMAD78301-05    AMAD  Ama Dablam  1978  Autumn   M  34.0
#
#   citizenship expedition_role  ...  highpoint_metres  success   solo  \
# 0      France          Leader  ...               NaN    False  False
# 1      France   Deputy Leader  ...            6000.0    False  False
# 2      France         Climber  ...               NaN    False  False
# 3      France      Exp Doctor  ...            6000.0    False  False
# 4      France         Climber  ...               NaN    False  False
#
#    oxygen_used   died  death_cause death_height_metres  injured  injury_type  \
# ...

# %%
data.tail()
# Out:
#       expedition_id     member_id peak_id        peak_name  year  season sex  \
# 76514     PUTH19101  PUTH19101-07    PUTH  Putha Hiunchuli  2019  Spring   M
# 76515     RATC19101  RATC19101-01    RATC      Ratna Chuli  2019  Spring   M
# 76516     SANK19101  SANK19101-01    SANK     Sano Kailash  2019  Spring   M
# 76517     SANK19101  SANK19101-02    SANK     Sano Kailash  2019  Spring   F
# 76518     SANK19101  SANK19101-03    SANK     Sano Kailash  2019  Spring   M
#
#         age citizenship expedition_role  ...  highpoint_metres  success  \
# 76514  44.0       Nepal      H-A Worker  ...            6350.0    False
# 76515  55.0     Romania          Leader  ...            6600.0    False
# 76516  56.0     Austria          Leader  ...            6452.0     True
# 76517  57.0     Austria         Climber  ...            5700.0    False
# 76518  41.0       Nepal      H-A Worker  ...            6452.0     True
#
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76519 entries, 0 to 76518
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   expedition_id         76519 non-null  object
#  1   member_id             76519 non-null  object
#  2   peak_id               76519 non-null  object
#  3   peak_name             76504 non-null  object
#  4   year                  76519 non-null  int64
#  5   season                76519 non-null  object
#  6   sex                   76517 non-null  object
#  7   age                   73022 non-null  float64
#  8   citizenship           76509 non-null  object
#  9   expedition_role       76498 non-null  object
#  10  hired                 76519 non-null  bool
#  11  highpoint_metres      54686 non-null  float64
#  12  success               76519 non-null  bool
#  13  solo                  76519 non-null  bool
#  14  oxygen_used           76519 non-null  bool
# ...

# %%
data = data.drop(columns=['expedition_id', 'member_id', 'peak_id', 'death_cause','injured', 'injury_type', 'injury_height_metres', 'sex', 'citizenship', 'expedition_role', 'highpoint_metres', 'solo', 'death_height_metres'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 76519 entries, 0 to 76518
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   peak_name    76504 non-null  object
#  1   year         76519 non-null  int64
#  2   season       76519 non-null  object
#  3   age          73022 non-null  float64
#  4   hired        76519 non-null  bool
#  5   success      76519 non-null  bool
#  6   oxygen_used  76519 non-null  bool
#  7   died         76519 non-null  bool
# dtypes: bool(4), float64(1), int64(1), object(2)
# memory usage: 2.6+ MB

# %%
data
# Out:
#              peak_name  year  season   age  hired  success  oxygen_used   died
# 0           Ama Dablam  1978  Autumn  40.0  False    False        False  False
# 1           Ama Dablam  1978  Autumn  41.0  False    False        False  False
# 2           Ama Dablam  1978  Autumn  27.0  False    False        False  False
# 3           Ama Dablam  1978  Autumn  40.0  False    False        False  False
# 4           Ama Dablam  1978  Autumn  34.0  False    False        False  False
# ...                ...   ...     ...   ...    ...      ...          ...    ...
# 76514  Putha Hiunchuli  2019  Spring  44.0   True    False        False  False
# 76515      Ratna Chuli  2019  Spring  55.0  False    False        False  False
# 76516     Sano Kailash  2019  Spring  56.0  False     True        False  False
# 76517     Sano Kailash  2019  Spring  57.0  False    False        False  False
# 76518     Sano Kailash  2019  Spring  41.0   True     True        False  False
#
# ...

# %%
data = data.dropna(subset= ['peak_name'])

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76504 entries, 0 to 76518
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   peak_name    76504 non-null  object
#  1   year         76504 non-null  int64
#  2   season       76504 non-null  object
#  3   age          73007 non-null  float64
#  4   hired        76504 non-null  bool
#  5   success      76504 non-null  bool
#  6   oxygen_used  76504 non-null  bool
#  7   died         76504 non-null  bool
# dtypes: bool(4), float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
median_age = data['age'].median()

# %%
data['age'] = data['age'].fillna(median_age)
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_7600\3797857117.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['age'] = data['age'].fillna(median_age)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76504 entries, 0 to 76518
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   peak_name    76504 non-null  object
#  1   year         76504 non-null  int64
#  2   season       76504 non-null  object
#  3   age          76504 non-null  float64
#  4   hired        76504 non-null  bool
#  5   success      76504 non-null  bool
#  6   oxygen_used  76504 non-null  bool
#  7   died         76504 non-null  bool
# dtypes: bool(4), float64(1), int64(1), object(2)
# memory usage: 3.2+ MB

# %%
data
# Out:
#              peak_name  year  season   age  hired  success  oxygen_used   died
# 0           Ama Dablam  1978  Autumn  40.0  False    False        False  False
# 1           Ama Dablam  1978  Autumn  41.0  False    False        False  False
# 2           Ama Dablam  1978  Autumn  27.0  False    False        False  False
# 3           Ama Dablam  1978  Autumn  40.0  False    False        False  False
# 4           Ama Dablam  1978  Autumn  34.0  False    False        False  False
# ...                ...   ...     ...   ...    ...      ...          ...    ...
# 76514  Putha Hiunchuli  2019  Spring  44.0   True    False        False  False
# 76515      Ratna Chuli  2019  Spring  55.0  False    False        False  False
# 76516     Sano Kailash  2019  Spring  56.0  False     True        False  False
# 76517     Sano Kailash  2019  Spring  57.0  False    False        False  False
# 76518     Sano Kailash  2019  Spring  41.0   True     True        False  False
#
# ...

# %%
data['age'] = data['age'].astype(int)
# Out:
# C:\Users\shahi\AppData\Local\Temp\ipykernel_7600\3403544981.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['age'] = data['age'].astype(int)

# %%
data
# Out:
#              peak_name  year  season  age  hired  success  oxygen_used   died
# 0           Ama Dablam  1978  Autumn   40  False    False        False  False
# 1           Ama Dablam  1978  Autumn   41  False    False        False  False
# 2           Ama Dablam  1978  Autumn   27  False    False        False  False
# 3           Ama Dablam  1978  Autumn   40  False    False        False  False
# 4           Ama Dablam  1978  Autumn   34  False    False        False  False
# ...                ...   ...     ...  ...    ...      ...          ...    ...
# 76514  Putha Hiunchuli  2019  Spring   44   True    False        False  False
# 76515      Ratna Chuli  2019  Spring   55  False    False        False  False
# 76516     Sano Kailash  2019  Spring   56  False     True        False  False
# 76517     Sano Kailash  2019  Spring   57  False    False        False  False
# 76518     Sano Kailash  2019  Spring   41   True     True        False  False
#
# [76504 rows x 8 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 76504 entries, 0 to 76518
# Data columns (total 8 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   peak_name    76504 non-null  object
#  1   year         76504 non-null  int64
#  2   season       76504 non-null  object
#  3   age          76504 non-null  int64
#  4   hired        76504 non-null  bool
#  5   success      76504 non-null  bool
#  6   oxygen_used  76504 non-null  bool
#  7   died         76504 non-null  bool
# dtypes: bool(4), int64(2), object(2)
# memory usage: 3.2+ MB

# %%
data.to_csv('cleaned_data', index=4)
